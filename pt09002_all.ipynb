# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy.fft import fft, ifft, dct, fftfreq
from scipy.fft import rfft, rfftfreq
from scipy import signal
# %matplotlib widget
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 7
#       5 from scipy.fft import rfft, rfftfreq
#       6 from scipy import signal
# ----> 7 get_ipython().run_line_magic('matplotlib', 'widget')
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:2432, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2430     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2431 with self.builtin_trap:
# -> 2432     result = fn(*args, **kwargs)
#    2434 # The code below prevents the output from being displayed
#    2435 # when using magics with decorator @output_can_be_silenced
#    2436 # when the last Python token in the expression is a ';'.
#    2437 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~\anaconda3\Lib\site-packages\IPython\core\magics\pylab.py:99, in PylabMagics.matplotlib(self, line)
#      97     print("Available matplotlib backends: %s" % backends_list)
#      98 else:
# ---> 99     gui, backend = self.shell.enable_matplotlib(args.gui.lower() if isinstance(args.gui, str) else args.gui)
#     100     self._show_matplotlib_backend(args.gui, backend)
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3621, in InteractiveShell.enable_matplotlib(self, gui)
#    3617         print('Warning: Cannot change to a different GUI toolkit: %s.'
#    3618                 ' Using %s instead.' % (gui, self.pylab_gui_select))
#    3619         gui, backend = pt.find_gui_and_backend(self.pylab_gui_select)
# -> 3621 pt.activate_matplotlib(backend)
#    3622 configure_inline_support(self, backend)
#    3624 # Now we must activate the gui pylab wants to use, and fix %run to take
#    3625 # plot updates into account
#
# File ~\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:368, in activate_matplotlib(backend)
#     363 # Due to circular imports, pyplot may be only partially initialised
#     364 # when this function runs.
#     365 # So avoid needing matplotlib attribute-lookup to access pyplot.
#     366 from matplotlib import pyplot as plt
# --> 368 plt.switch_backend(backend)
#     370 plt.show._needmain = False
#     371 # We need to detect at runtime whether show() is called by the user.
#     372 # For this, we wrap it into a decorator which adds a 'called' flag.
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:271, in switch_backend(newbackend)
#     268 # have to escape the switch on access logic
#     269 old_backend = dict.__getitem__(rcParams, 'backend')
# --> 271 backend_mod = importlib.import_module(
#     272     cbook._backend_module_name(newbackend))
#     274 required_framework = _get_required_interactive_framework(backend_mod)
#     275 if required_framework is not None:
#
# File ~\anaconda3\Lib\importlib\__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1204, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1126, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File <frozen importlib._bootstrap>:1204, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1140, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'ipympl'

# %%
def read_THz(fname):
    df = pd.read_csv(fname, sep='\t') 
    time = np.array(df.values[:,0]).astype(float)
    pulse = np.array(df.values[:,1]).astype(float)
    return time, pulse

# %%
time_bkg, pulse_bkg = read_THz(r"C:\Users\prosp\Documents\FYS 203-JAN\LAB_THZ_DATA\2024_01_23\pt09002\160_200\background_160_200__V_u.txt")
time_pc, pulse_pc = read_THz(r"C:\Users\prosp\Documents\FYS 203-JAN\LAB_THZ_DATA\2024_01_23\pt09002\160_200\pt09002_160_200_rep1__V_u.txt")
time_bkg_2, pulse_bkg_2 = read_THz(r"C:\Users\prosp\Documents\FYS 203-JAN\LAB_THZ_DATA\2024_01_23\pt09002\160_220\background_160_220____V_u.txt")
time_pc_2, pulse_pc_2 = read_THz(r"C:\Users\prosp\Documents\FYS 203-JAN\LAB_THZ_DATA\2024_01_23\pt09002\160_220\pt09002_160_220_rep1__V_u.txt")
time_bkg_3, pulse_bkg_3 = read_THz(r"C:\Users\prosp\Documents\FYS 203-JAN\LAB_THZ_DATA\2024_01_23\pt09002\160_260\background_160_260__V_u.txt")
time_pc_3, pulse_pc_3 = read_THz(r"C:\Users\prosp\Documents\FYS 203-JAN\LAB_THZ_DATA\2024_01_23\pt09002\160_260\pt09002_160_260_rep1__V_u.txt")

plt.figure()
plt.plot(time_bkg, pulse_bkg,label='background_20ps')
plt.plot(time_pc, pulse_pc,label='pt09002_20ps')
plt.plot(time_bkg_2, pulse_bkg_2,label='background_160_220')
plt.plot(time_pc_2, pulse_pc_2,label='pt09002_40ps')
plt.plot(time_bkg_3, pulse_bkg_3,label='background_160_260')
plt.plot(time_pc_3, pulse_pc_3,label='pt09002_80ps')
plt.xlabel('Time [ps]')
plt.ylabel('Amplitude') 
plt.grid(color=[0.7, 0.7, 0.7], linestyle='--')
plt.legend()

# %%
dt = time_bkg[1] - time_bkg[0]
freq = rfftfreq(len(time_bkg),dt)
polycarbonate_spectrum = np.abs(rfft(pulse_pc)) #convert time to freq
polycarbonate_spectrum_2= np.abs(rfft(pulse_pc_2)) 
polycarbonate_spectrum_3= np.abs(rfft(pulse_pc_3)) 
bkg_spectrum = np.abs(rfft(pulse_bkg))

plt.figure(figsize = (12,6))
plt.plot(freq, polycarbonate_spectrum , label = "pt09002_20ps")
plt.plot(freq, polycarbonate_spectrum_2, label = "pt09002_40ps")
plt.plot(freq, polycarbonate_spectrum_3, label = "pt09002_80ps")
plt.plot(freq, bkg_spectrum , label = "background")
           
plt.xlabel("Frequency[THz]")   
plt.ylabel("Amplitude")
plt.xlim(0,2)
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 10
#       8 plt.figure(figsize = (12,6))
#       9 plt.plot(freq, polycarbonate_spectrum , label = "pt09002_20ps")
# ---> 10 plt.plot(freq, polycarbonate_spectrum_2, label = "pt09002_40ps")
#      11 plt.plot(freq, polycarbonate_spectrum_3, label = "pt09002_80ps")
#      12 plt.plot(freq, bkg_spectrum , label = "background")
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:2812, in plot(scalex, scaley, data, *args, **kwargs)
#    2810 @_copy_docstring_and_deprecators(Axes.plot)
#    2811 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2812     return gca().plot(
#    2813         *args, scalex=scalex, scaley=scaley,
#    2814         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\axes\_axes.py:1688, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1445 """
#    1446 Plot y versus x as lines and/or markers.
#    1447
#    (...)
#    1685 (``'green'``) or hex strings (``'#008000'``).
#    1686 """
#    1687 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1688 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1689 for line in lines:
#    1690     self.add_line(line)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\axes\_base.py:311, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     309     this += args[0],
#     310     args = args[1:]
# --> 311 yield from self._plot_args(
#     312     this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\axes\_base.py:504, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     501     self.axes.yaxis.update_units(y)
#     503 if x.shape[0] != y.shape[0]:
# --> 504     raise ValueError(f"x and y must have same first dimension, but "
#     505                      f"have shapes {x.shape} and {y.shape}")
#     506 if x.ndim > 2 or y.ndim > 2:
#     507     raise ValueError(f"x and y can be no greater than 2D, but have "
#     508                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (641,) and (961,)

# %%
len(polycarbonate_spectrum)
# Out:
# 641

# %%
len(polycarbonate_spectrum_2)
# Out:
# 961

# %%
len(polycarbonate_spectrum_3)
# Out:
# 1280

# %%
# Zero-padding to match the length
pad_length_2 = len(polycarbonate_spectrum) - len(polycarbonate_spectrum_2)
pad_length_3 = len(polycarbonate_spectrum) - len(polycarbonate_spectrum_3)
pad_length_bkg = len(polycarbonate_spectrum) - len(bkg_spectrum)

# Padding other spectra
polycarbonate_spectrum_2 = np.pad(polycarbonate_spectrum_2, (0, pad_length_2), mode='constant', constant_values=0)
polycarbonate_spectrum_3 = np.pad(polycarbonate_spectrum_3, (0, pad_length_3), mode='constant', constant_values=0)
bkg_spectrum = np.pad(bkg_spectrum, (0, pad_length_bkg), mode='constant', constant_values=0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 7
#       4 pad_length_bkg = len(polycarbonate_spectrum) - len(bkg_spectrum)
#       6 # Padding other spectra
# ----> 7 polycarbonate_spectrum_2 = np.pad(polycarbonate_spectrum_2, (0, pad_length_2), mode='constant', constant_values=0)
#       8 polycarbonate_spectrum_3 = np.pad(polycarbonate_spectrum_3, (0, pad_length_3), mode='constant', constant_values=0)
#       9 bkg_spectrum = np.pad(bkg_spectrum, (0, pad_length_bkg), mode='constant', constant_values=0)
#
# File ~\anaconda3\envs\inf250\lib\site-packages\numpy\lib\arraypad.py:748, in pad(array, pad_width, mode, **kwargs)
#     745     raise TypeError('`pad_width` must be of integral type.')
#     747 # Broadcast to shape (array.ndim, 2)
# --> 748 pad_width = _as_pairs(pad_width, array.ndim, as_index=True)
#     750 if callable(mode):
#     751     # Old behavior: Use user-supplied function with np.apply_along_axis
#     752     function = mode
#
# File ~\anaconda3\envs\inf250\lib\site-packages\numpy\lib\arraypad.py:514, in _as_pairs(x, ndim, as_index)
#     512         x = x.ravel()  # Ensure x[0], x[1] works
#     513         if as_index and (x[0] < 0 or x[1] < 0):
# --> 514             raise ValueError("index can't contain negative values")
#     515         return ((x[0], x[1]),) * ndim
#     517 if as_index and x.min() < 0:
#
# ValueError: index can't contain negative values

# %%
dt = time_bkg[1] - time_bkg[0]
freq = rfftfreq(len(time_bkg),dt)
polycarbonate_spectrum = np.abs(rfft(pulse_pc))   #convert time to freq
bkg_spectrum = np.abs(rfft(pulse_bkg))

plt.figure(figsize = (12,6))
plt.plot(freq, polycarbonate_spectrum , label = "pt09002_160_200")
plt.plot(freq, bkg_spectrum , label = "background")
           
plt.xlabel("Frequency[THz]")   
plt.ylabel("Amplitude")
plt.xlim(0,2)
plt.legend()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
abs_pc = -np.log(polycarbonate_spectrum/bkg_spectrum)
plt.figure(figsize = (12,6))
plt.plot(freq, abs_pc , label = "pt09002_160_200")

           
plt.xlabel("Frequency[THz]")   
plt.ylabel("Absorbance")
plt.title("Absorbance for Pt09002_160_200")
plt.xlim(0,2)
plt.legend()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
N = len(pulse_bkg)
pulse_bkg_zp = np.hstack((pulse_bkg,np.zeros(N)))
pulse_pc_zp = np.hstack((pulse_pc,np.zeros(N)))

plt.figure()
plt.plot(pulse_bkg_zp)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
freq_zp = rfftfreq(len(pulse_bkg_zp),dt)


polycarbonate_spectrum_zp = np.abs(rfft(pulse_pc_zp))   #convert time to freq
bkg_spectrum_zp = np.abs(rfft(pulse_bkg_zp))

plt.figure(figsize = (12,6))
plt.plot(freq_zp, polycarbonate_spectrum_zp , label = "pt09002_160_200")
plt.plot(freq_zp, bkg_spectrum_zp , label = "background")
           
plt.xlabel("Frequency[THz]")   
plt.ylabel("Amplitude")
plt.title("zero padding")
plt.xlim(0,2)
plt.legend()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
abs_pc_zp = -np.log(polycarbonate_spectrum_zp/bkg_spectrum_zp)
plt.figure(figsize = (12,6))
plt.plot(freq_zp, abs_pc_zp, label = "zeropad_pt09002_160_200")
plt.plot(freq, abs_pc , label = "raw")
          
plt.xlabel("Frequency[THz]")   
plt.ylabel("Absorbance")
plt.xlim(0,2)
plt.title("Zero padding ABS for Pt09009")
plt.legend()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
peak_pos_bkg = np.argmax(pulse_bkg_zp)
peak_pos_pc = np.argmax(pulse_pc_zp)

window_size = peak_pos_bkg * 2
window = signal.blackmanharris(window_size)

window_bkg = np.zeros(len(pulse_bkg_zp))
window_bkg[int(peak_pos_bkg-window_size/2): int(peak_pos_bkg+window_size/2)] = window
window_pc = np.zeros(len(pulse_pc_zp))
window_pc[int(peak_pos_pc-window_size/2): int(peak_pos_pc+window_size/2)] = window

plt.figure()
plt.plot(window_bkg*np.max(pulse_bkg_zp),"g")
plt.plot(pulse_bkg_zp)
plt.plot(window_bkg*pulse_bkg_zp,"b")


plt.figure()
plt.plot(window_pc*np.max(pulse_pc_zp),"g")
plt.plot(pulse_pc_zp)
plt.plot(window_pc*pulse_pc_zp,"b")
# Out:
# C:\Users\prosp\AppData\Local\Temp\ipykernel_10304\552016791.py:5: DeprecationWarning: Importing blackmanharris from 'scipy.signal' is deprecated and will raise an error in SciPy 1.13.0. Please use 'scipy.signal.windows.blackmanharris' or the convenience function 'scipy.signal.get_window' instead.
#   window = signal.blackmanharris(window_size)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
polycarbonate_spectrum_zp_window = np.abs(rfft(window_pc*pulse_pc_zp))   #convert time to freq
bkg_spectrum_zp_window = np.abs(rfft(window_bkg*pulse_bkg_zp))

plt.figure(figsize = (12,6))
plt.plot(freq_zp, polycarbonate_spectrum_zp_window, label = "pt09002_160_200")
plt.plot(freq_zp, bkg_spectrum_zp_window, label = "background")
           
plt.xlabel("Frequency[THz]")   
plt.ylabel("Amplitude")
plt.title("zero padding+window_fxn")
plt.xlim(0,2)
plt.legend()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
abs_pc_window = -np.log(polycarbonate_spectrum_zp_window/bkg_spectrum_zp_window)
plt.figure(figsize = (12,6))
plt.plot(freq_zp, abs_pc_window , label = "window+zeropadded")
plt.plot(freq_zp, abs_pc_zp, label = "zeropad")
plt.plot(freq, abs_pc , label = "raw")
           
plt.xlabel("Frequency[THz]")   
plt.ylabel("Absorbance")
plt.xlim(0,2)
plt.title("Absorbance for Pt09002_160_200")
plt.legend()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
